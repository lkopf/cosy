# %% [markdown]
# # Explore one prompt at a time
# This notebook is meant to explore the process of collecting concepts. The user can vary the prompt, the layers and the number of images to use for the prompt.

# %%
import os
import time 

import argparse
import asyncio
import csv
import numpy as np
import random

import torch 

import openai
import base64

from utils import *

# %%
np.random.seed(0)
random.seed(0)

# %%
client = openai.OpenAI(
    api_key="INSERT YOUR KEY HERE")

# %%
prompts = {'0': ( "You are a visual concept tagger and compressor. Given one or a group of images that activate the same neuron, your job is to extract a single, specific visual concept that appears prominently in all of them. This concept must be: - Concrete (e.g., 'red double-decker bus', not 'transportation') - Visual (can be drawn by an image generation model like SDXL) - Consistent (appears in every image). Avoid vague or abstract themes like 'diversity', 'context', or 'life'. For example, do not use 'animal' but specify what kind of animal or characteristics of the animal. Focus on visible entities (objects, creatures, materials, or actions). Output only the final concept that occurs in all images, no other text. Always output only a visual concept, if there is not a clear one, get the most likely. Do not state that there is no clear visual concept, just output the concept" )}

IMAGE_NUMBER = [1,5,10,15,20]

LAYERS = [1,2,3,4]

# %%
def prompt_single(top_x_indices, prompt=None):
    if prompt is None:
        prompt = (
            "Here are several images that activate the same neuron. "
            "Identify a concrete, tangible visual concept that appears in all of them. "
            "Be specific—focus on objects, environments, or actions that visually dominate the images. "
            "The concept should be easily representable in an image generation model like SDXL. "
            "Output only the final concept, no additional text."
        )

    encoded_images = get_image_from_indices(top_x_indices)  # returns list of base64 strings

    messages = [
        {"role": "system", "content": "You are a visual concept tagger for neuroscience research."},
        {
            "role": "user",
            "content": [
                {"type": "text", "text": prompt},
                *[
                    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{img[0]}"}}
                    for img in encoded_images
                ]
            ]
        }
    ]

    try:
        response = client.chat.completions.create(
            model="gpt-4o",#"azure/gpt-4o",
            messages=messages,
            timeout=60
        )
        return response.choices[0].message.content.strip()

    except openai.OpenAIError as e:
        print(f"OpenAI API error: {e}")
        return None

# %%
for layer in LAYERS:

    activation_path =f'/cosy/LLM_activations/activations/val_resnet18-layer{layer}.pt'

    # Load the activations 
    print(f"Loading activations from: {activation_path}")
    activations = torch.load(activation_path)
    print("Activation shape:", activations.shape)

    top_x_indices = retrieve_top_x_indices(activations, image_number)
    print("Top-X indices shape:", top_x_indices.shape)

    # take 50 random neurons: create a random sample of 50 indices and then take the corresponding neurons
    random_indices = np.random.choice(top_x_indices.shape[0], size=50, replace=False)
    top_50 = top_x_indices[random_indices]
    print("Random sample shape:", top_x_indices.shape)

    for image_number in IMAGE_NUMBER:

        start_time = time.time()

        responses = []
        for i, image_indices in enumerate(top_50):    

            neuron_indice = random_indices[i]

            print(f"Prompting neuron {neuron_indice + 1}...")
            concept = prompt_single(top_x_indices=image_indices.tolist(), prompt=list(prompts.values())[0])
            responses.append(concept)

            time.sleep(10)

        print("Number of responses:", len(responses))

        csv_file_path = f"experiments/prompts_1/layer_{layer}_{image_number}.csv"

        # Prepare the data for writing
        data_to_write = []
        for unit, neuron_indices in enumerate(top_50):
            concept = responses[unit] if unit < len(responses) else None
            neuron = random_indices[unit]
            data_to_write.append([layer, neuron, concept])

        # Write to the CSV file
        with open(csv_file_path, mode="w", newline="") as file:
            writer = csv.writer(file)
            writer.writerow(["layer", "unit", "description"])  # Write header
            writer.writerows(data_to_write)

        print(f"Data successfully written to {csv_file_path}")

prompt_file_path = f"experiments/prompts_1/prompt.txt"
with open(prompt_file_path, "w") as prompt_file:
    prompt_file.write(prompts['0'])
print(f"Prompt successfully written to {prompt_file_path}")
# Out:
# Loading activations from: /Users/sinievanderben/Documents/ETH/tech/cosy/LLM_activations/activations/val_resnet18-layer1.pt
# Activation shape: torch.Size([50000, 64])
# Top-X indices shape: torch.Size([64, 1])
# Random sample shape: torch.Size([64, 1])
# Prompting neuron 56...
# Prompting neuron 25...
# Prompting neuron 20...
# Prompting neuron 46...
# Prompting neuron 9...
# Prompting neuron 37...
# Prompting neuron 55...
# Prompting neuron 61...
# Prompting neuron 29...
# Prompting neuron 8...
# Prompting neuron 60...
# Prompting neuron 11...
# Prompting neuron 49...
# Prompting neuron 33...
# Prompting neuron 31...
# Prompting neuron 34...
# Prompting neuron 3...
# Prompting neuron 53...
# Prompting neuron 50...
# Prompting neuron 27...
# Prompting neuron 23...
# Prompting neuron 26...
# Prompting neuron 48...
# Prompting neuron 38...
# Prompting neuron 10...
# Prompting neuron 6...
# Prompting neuron 18...
# Prompting neuron 17...
# Prompting neuron 30...
# Prompting neuron 22...
# Prompting neuron 14...
# Prompting neuron 35...
# Prompting neuron 24...
# Prompting neuron 44...
# Prompting neuron 16...
# Prompting neuron 51...
# Prompting neuron 45...
# Prompting neuron 4...
# Prompting neuron 41...
# Prompting neuron 7...
# Prompting neuron 64...
# Prompting neuron 52...
# Prompting neuron 21...
# Prompting neuron 62...
# Prompting neuron 13...
# Prompting neuron 54...
# Prompting neuron 15...
# Prompting neuron 1...
# Prompting neuron 28...
# Prompting neuron 19...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_1_1.csv
# Prompting neuron 56...
# Prompting neuron 25...
# Prompting neuron 20...
# Prompting neuron 46...
# Prompting neuron 9...
# Prompting neuron 37...
# Prompting neuron 55...
# Prompting neuron 61...
# Prompting neuron 29...
# Prompting neuron 8...
# Prompting neuron 60...
# Prompting neuron 11...
# Prompting neuron 49...
# Prompting neuron 33...
# Prompting neuron 31...
# Prompting neuron 34...
# Prompting neuron 3...
# Prompting neuron 53...
# Prompting neuron 50...
# Prompting neuron 27...
# Prompting neuron 23...
# Prompting neuron 26...
# Prompting neuron 48...
# Prompting neuron 38...
# Prompting neuron 10...
# Prompting neuron 6...
# Prompting neuron 18...
# Prompting neuron 17...
# Prompting neuron 30...
# Prompting neuron 22...
# Prompting neuron 14...
# Prompting neuron 35...
# Prompting neuron 24...
# Prompting neuron 44...
# Prompting neuron 16...
# Prompting neuron 51...
# Prompting neuron 45...
# Prompting neuron 4...
# Prompting neuron 41...
# Prompting neuron 7...
# Prompting neuron 64...
# Prompting neuron 52...
# Prompting neuron 21...
# Prompting neuron 62...
# Prompting neuron 13...
# Prompting neuron 54...
# Prompting neuron 15...
# Prompting neuron 1...
# Prompting neuron 28...
# Prompting neuron 19...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_1_5.csv
# Prompting neuron 56...
# Prompting neuron 25...
# Prompting neuron 20...
# Prompting neuron 46...
# Prompting neuron 9...
# Prompting neuron 37...
# Prompting neuron 55...
# Prompting neuron 61...
# Prompting neuron 29...
# Prompting neuron 8...
# Prompting neuron 60...
# Prompting neuron 11...
# Prompting neuron 49...
# Prompting neuron 33...
# Prompting neuron 31...
# Prompting neuron 34...
# Prompting neuron 3...
# Prompting neuron 53...
# Prompting neuron 50...
# Prompting neuron 27...
# Prompting neuron 23...
# Prompting neuron 26...
# Prompting neuron 48...
# Prompting neuron 38...
# Prompting neuron 10...
# Prompting neuron 6...
# Prompting neuron 18...
# Prompting neuron 17...
# Prompting neuron 30...
# Prompting neuron 22...
# Prompting neuron 14...
# Prompting neuron 35...
# Prompting neuron 24...
# Prompting neuron 44...
# Prompting neuron 16...
# Prompting neuron 51...
# Prompting neuron 45...
# Prompting neuron 4...
# Prompting neuron 41...
# Prompting neuron 7...
# Prompting neuron 64...
# Prompting neuron 52...
# Prompting neuron 21...
# Prompting neuron 62...
# Prompting neuron 13...
# Prompting neuron 54...
# Prompting neuron 15...
# Prompting neuron 1...
# Prompting neuron 28...
# Prompting neuron 19...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_1_10.csv
# Prompting neuron 56...
# Prompting neuron 25...
# Prompting neuron 20...
# Prompting neuron 46...
# Prompting neuron 9...
# Prompting neuron 37...
# Prompting neuron 55...
# Prompting neuron 61...
# Prompting neuron 29...
# Prompting neuron 8...
# Prompting neuron 60...
# Prompting neuron 11...
# Prompting neuron 49...
# Prompting neuron 33...
# Prompting neuron 31...
# Prompting neuron 34...
# Prompting neuron 3...
# Prompting neuron 53...
# Prompting neuron 50...
# Prompting neuron 27...
# Prompting neuron 23...
# Prompting neuron 26...
# Prompting neuron 48...
# Prompting neuron 38...
# Prompting neuron 10...
# Prompting neuron 6...
# Prompting neuron 18...
# Prompting neuron 17...
# Prompting neuron 30...
# Prompting neuron 22...
# Prompting neuron 14...
# Prompting neuron 35...
# Prompting neuron 24...
# Prompting neuron 44...
# Prompting neuron 16...
# Prompting neuron 51...
# Prompting neuron 45...
# Prompting neuron 4...
# Prompting neuron 41...
# Prompting neuron 7...
# Prompting neuron 64...
# Prompting neuron 52...
# Prompting neuron 21...
# Prompting neuron 62...
# Prompting neuron 13...
# Prompting neuron 54...
# Prompting neuron 15...
# Prompting neuron 1...
# Prompting neuron 28...
# Prompting neuron 19...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_1_15.csv
# Prompting neuron 56...
# Prompting neuron 25...
# Prompting neuron 20...
# Prompting neuron 46...
# Prompting neuron 9...
# Prompting neuron 37...
# Prompting neuron 55...
# Prompting neuron 61...
# Prompting neuron 29...
# Prompting neuron 8...
# Prompting neuron 60...
# Prompting neuron 11...
# Prompting neuron 49...
# Prompting neuron 33...
# Prompting neuron 31...
# Prompting neuron 34...
# Prompting neuron 3...
# Prompting neuron 53...
# Prompting neuron 50...
# Prompting neuron 27...
# Prompting neuron 23...
# Prompting neuron 26...
# Prompting neuron 48...
# Prompting neuron 38...
# Prompting neuron 10...
# Prompting neuron 6...
# Prompting neuron 18...
# Prompting neuron 17...
# Prompting neuron 30...
# Prompting neuron 22...
# Prompting neuron 14...
# Prompting neuron 35...
# Prompting neuron 24...
# Prompting neuron 44...
# Prompting neuron 16...
# Prompting neuron 51...
# Prompting neuron 45...
# Prompting neuron 4...
# Prompting neuron 41...
# Prompting neuron 7...
# Prompting neuron 64...
# Prompting neuron 52...
# Prompting neuron 21...
# Prompting neuron 62...
# Prompting neuron 13...
# Prompting neuron 54...
# Prompting neuron 15...
# Prompting neuron 1...
# Prompting neuron 28...
# Prompting neuron 19...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_1_20.csv
# Loading activations from: /Users/sinievanderben/Documents/ETH/tech/cosy/LLM_activations/activations/val_resnet18-layer2.pt
# Activation shape: torch.Size([50000, 128])
# Top-X indices shape: torch.Size([128, 20])
# Random sample shape: torch.Size([128, 20])
# Prompting neuron 90...
# Prompting neuron 109...
# Prompting neuron 75...
# Prompting neuron 110...
# Prompting neuron 72...
# Prompting neuron 127...
# Prompting neuron 105...
# Prompting neuron 49...
# Prompting neuron 101...
# Prompting neuron 113...
# Prompting neuron 71...
# Prompting neuron 80...
# Prompting neuron 124...
# Prompting neuron 46...
# Prompting neuron 10...
# Prompting neuron 54...
# Prompting neuron 18...
# Prompting neuron 38...
# Prompting neuron 76...
# Prompting neuron 64...
# Prompting neuron 88...
# Prompting neuron 29...
# Prompting neuron 48...
# Prompting neuron 123...
# Prompting neuron 45...
# Prompting neuron 35...
# Prompting neuron 107...
# Prompting neuron 116...
# Prompting neuron 9...
# Prompting neuron 94...
# Prompting neuron 98...
# Prompting neuron 121...
# Prompting neuron 128...
# Prompting neuron 6...
# Prompting neuron 23...
# Prompting neuron 125...
# Prompting neuron 13...
# Prompting neuron 40...
# Prompting neuron 50...
# Prompting neuron 106...
# Prompting neuron 114...
# Prompting neuron 79...
# Prompting neuron 56...
# Prompting neuron 2...
# Prompting neuron 69...
# Prompting neuron 97...
# Prompting neuron 115...
# Prompting neuron 102...
# Prompting neuron 65...
# Prompting neuron 19...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_2_1.csv
# Prompting neuron 90...
# Prompting neuron 109...
# Prompting neuron 75...
# Prompting neuron 110...
# Prompting neuron 72...
# Prompting neuron 127...
# Prompting neuron 105...
# Prompting neuron 49...
# Prompting neuron 101...
# Prompting neuron 113...
# Prompting neuron 71...
# Prompting neuron 80...
# Prompting neuron 124...
# Prompting neuron 46...
# Prompting neuron 10...
# Prompting neuron 54...
# Prompting neuron 18...
# Prompting neuron 38...
# Prompting neuron 76...
# Prompting neuron 64...
# Prompting neuron 88...
# Prompting neuron 29...
# Prompting neuron 48...
# Prompting neuron 123...
# Prompting neuron 45...
# Prompting neuron 35...
# Prompting neuron 107...
# Prompting neuron 116...
# Prompting neuron 9...
# Prompting neuron 94...
# Prompting neuron 98...
# Prompting neuron 121...
# Prompting neuron 128...
# Prompting neuron 6...
# Prompting neuron 23...
# Prompting neuron 125...
# Prompting neuron 13...
# Prompting neuron 40...
# Prompting neuron 50...
# Prompting neuron 106...
# Prompting neuron 114...
# Prompting neuron 79...
# Prompting neuron 56...
# Prompting neuron 2...
# Prompting neuron 69...
# Prompting neuron 97...
# Prompting neuron 115...
# Prompting neuron 102...
# Prompting neuron 65...
# Prompting neuron 19...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_2_5.csv
# Prompting neuron 90...
# Prompting neuron 109...
# Prompting neuron 75...
# Prompting neuron 110...
# Prompting neuron 72...
# Prompting neuron 127...
# Prompting neuron 105...
# Prompting neuron 49...
# Prompting neuron 101...
# Prompting neuron 113...
# Prompting neuron 71...
# Prompting neuron 80...
# Prompting neuron 124...
# Prompting neuron 46...
# Prompting neuron 10...
# Prompting neuron 54...
# Prompting neuron 18...
# Prompting neuron 38...
# Prompting neuron 76...
# Prompting neuron 64...
# Prompting neuron 88...
# Prompting neuron 29...
# Prompting neuron 48...
# Prompting neuron 123...
# Prompting neuron 45...
# Prompting neuron 35...
# Prompting neuron 107...
# Prompting neuron 116...
# Prompting neuron 9...
# Prompting neuron 94...
# Prompting neuron 98...
# Prompting neuron 121...
# Prompting neuron 128...
# Prompting neuron 6...
# Prompting neuron 23...
# Prompting neuron 125...
# Prompting neuron 13...
# Prompting neuron 40...
# Prompting neuron 50...
# Prompting neuron 106...
# Prompting neuron 114...
# Prompting neuron 79...
# Prompting neuron 56...
# Prompting neuron 2...
# Prompting neuron 69...
# Prompting neuron 97...
# Prompting neuron 115...
# Prompting neuron 102...
# Prompting neuron 65...
# Prompting neuron 19...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_2_10.csv
# Prompting neuron 90...
# Prompting neuron 109...
# Prompting neuron 75...
# Prompting neuron 110...
# Prompting neuron 72...
# Prompting neuron 127...
# Prompting neuron 105...
# Prompting neuron 49...
# Prompting neuron 101...
# Prompting neuron 113...
# Prompting neuron 71...
# Prompting neuron 80...
# Prompting neuron 124...
# Prompting neuron 46...
# Prompting neuron 10...
# Prompting neuron 54...
# Prompting neuron 18...
# Prompting neuron 38...
# Prompting neuron 76...
# Prompting neuron 64...
# Prompting neuron 88...
# Prompting neuron 29...
# Prompting neuron 48...
# Prompting neuron 123...
# Prompting neuron 45...
# Prompting neuron 35...
# Prompting neuron 107...
# Prompting neuron 116...
# Prompting neuron 9...
# Prompting neuron 94...
# Prompting neuron 98...
# Prompting neuron 121...
# Prompting neuron 128...
# Prompting neuron 6...
# Prompting neuron 23...
# Prompting neuron 125...
# Prompting neuron 13...
# Prompting neuron 40...
# Prompting neuron 50...
# Prompting neuron 106...
# Prompting neuron 114...
# Prompting neuron 79...
# Prompting neuron 56...
# Prompting neuron 2...
# Prompting neuron 69...
# Prompting neuron 97...
# Prompting neuron 115...
# Prompting neuron 102...
# Prompting neuron 65...
# Prompting neuron 19...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_2_15.csv
# Prompting neuron 90...
# Prompting neuron 109...
# Prompting neuron 75...
# Prompting neuron 110...
# Prompting neuron 72...
# Prompting neuron 127...
# Prompting neuron 105...
# Prompting neuron 49...
# Prompting neuron 101...
# Prompting neuron 113...
# Prompting neuron 71...
# Prompting neuron 80...
# Prompting neuron 124...
# Prompting neuron 46...
# Prompting neuron 10...
# Prompting neuron 54...
# Prompting neuron 18...
# Prompting neuron 38...
# Prompting neuron 76...
# Prompting neuron 64...
# Prompting neuron 88...
# Prompting neuron 29...
# Prompting neuron 48...
# Prompting neuron 123...
# Prompting neuron 45...
# Prompting neuron 35...
# Prompting neuron 107...
# Prompting neuron 116...
# Prompting neuron 9...
# Prompting neuron 94...
# Prompting neuron 98...
# Prompting neuron 121...
# Prompting neuron 128...
# Prompting neuron 6...
# Prompting neuron 23...
# Prompting neuron 125...
# Prompting neuron 13...
# Prompting neuron 40...
# Prompting neuron 50...
# Prompting neuron 106...
# Prompting neuron 114...
# Prompting neuron 79...
# Prompting neuron 56...
# Prompting neuron 2...
# Prompting neuron 69...
# Prompting neuron 97...
# Prompting neuron 115...
# Prompting neuron 102...
# Prompting neuron 65...
# Prompting neuron 19...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_2_20.csv
# Loading activations from: /Users/sinievanderben/Documents/ETH/tech/cosy/LLM_activations/activations/val_resnet18-layer3.pt
# Activation shape: torch.Size([50000, 256])
# Top-X indices shape: torch.Size([256, 20])
# Random sample shape: torch.Size([256, 20])
# Prompting neuron 91...
# Prompting neuron 256...
# Prompting neuron 216...
# Prompting neuron 203...
# Prompting neuron 78...
# Prompting neuron 16...
# Prompting neuron 110...
# Prompting neuron 12...
# Prompting neuron 160...
# Prompting neuron 154...
# Prompting neuron 243...
# Prompting neuron 252...
# Prompting neuron 253...
# Prompting neuron 218...
# Prompting neuron 172...
# Prompting neuron 41...
# Prompting neuron 116...
# Prompting neuron 194...
# Prompting neuron 155...
# Prompting neuron 38...
# Prompting neuron 207...
# Prompting neuron 63...
# Prompting neuron 242...
# Prompting neuron 109...
# Prompting neuron 46...
# Prompting neuron 225...
# Prompting neuron 22...
# Prompting neuron 99...
# Prompting neuron 97...
# Prompting neuron 235...
# Prompting neuron 170...
# Prompting neuron 119...
# Prompting neuron 125...
# Prompting neuron 192...
# Prompting neuron 202...
# Prompting neuron 51...
# Prompting neuron 111...
# Prompting neuron 186...
# Prompting neuron 152...
# Prompting neuron 240...
# Prompting neuron 87...
# Prompting neuron 47...
# Prompting neuron 128...
# Prompting neuron 223...
# Prompting neuron 77...
# Prompting neuron 2...
# Prompting neuron 215...
# Prompting neuron 250...
# Prompting neuron 120...
# Prompting neuron 103...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_3_1.csv
# Prompting neuron 91...
# Prompting neuron 256...
# Prompting neuron 216...
# Prompting neuron 203...
# Prompting neuron 78...
# Prompting neuron 16...
# Prompting neuron 110...
# Prompting neuron 12...
# Prompting neuron 160...
# Prompting neuron 154...
# Prompting neuron 243...
# Prompting neuron 252...
# Prompting neuron 253...
# Prompting neuron 218...
# Prompting neuron 172...
# Prompting neuron 41...
# Prompting neuron 116...
# Prompting neuron 194...
# Prompting neuron 155...
# Prompting neuron 38...
# Prompting neuron 207...
# Prompting neuron 63...
# Prompting neuron 242...
# Prompting neuron 109...
# Prompting neuron 46...
# Prompting neuron 225...
# Prompting neuron 22...
# Prompting neuron 99...
# Prompting neuron 97...
# Prompting neuron 235...
# Prompting neuron 170...
# Prompting neuron 119...
# Prompting neuron 125...
# Prompting neuron 192...
# Prompting neuron 202...
# Prompting neuron 51...
# Prompting neuron 111...
# Prompting neuron 186...
# Prompting neuron 152...
# Prompting neuron 240...
# Prompting neuron 87...
# Prompting neuron 47...
# Prompting neuron 128...
# Prompting neuron 223...
# Prompting neuron 77...
# Prompting neuron 2...
# Prompting neuron 215...
# Prompting neuron 250...
# Prompting neuron 120...
# Prompting neuron 103...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_3_5.csv
# Prompting neuron 91...
# Prompting neuron 256...
# Prompting neuron 216...
# Prompting neuron 203...
# Prompting neuron 78...
# Prompting neuron 16...
# Prompting neuron 110...
# Prompting neuron 12...
# Prompting neuron 160...
# Prompting neuron 154...
# Prompting neuron 243...
# Prompting neuron 252...
# Prompting neuron 253...
# Prompting neuron 218...
# Prompting neuron 172...
# Prompting neuron 41...
# Prompting neuron 116...
# Prompting neuron 194...
# Prompting neuron 155...
# Prompting neuron 38...
# Prompting neuron 207...
# Prompting neuron 63...
# Prompting neuron 242...
# Prompting neuron 109...
# Prompting neuron 46...
# Prompting neuron 225...
# Prompting neuron 22...
# Prompting neuron 99...
# Prompting neuron 97...
# Prompting neuron 235...
# Prompting neuron 170...
# Prompting neuron 119...
# Prompting neuron 125...
# Prompting neuron 192...
# Prompting neuron 202...
# Prompting neuron 51...
# Prompting neuron 111...
# Prompting neuron 186...
# Prompting neuron 152...
# Prompting neuron 240...
# Prompting neuron 87...
# Prompting neuron 47...
# Prompting neuron 128...
# Prompting neuron 223...
# Prompting neuron 77...
# Prompting neuron 2...
# Prompting neuron 215...
# Prompting neuron 250...
# Prompting neuron 120...
# Prompting neuron 103...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_3_10.csv
# Prompting neuron 91...
# Prompting neuron 256...
# Prompting neuron 216...
# Prompting neuron 203...
# Prompting neuron 78...
# Prompting neuron 16...
# Prompting neuron 110...
# Prompting neuron 12...
# Prompting neuron 160...
# Prompting neuron 154...
# Prompting neuron 243...
# Prompting neuron 252...
# Prompting neuron 253...
# Prompting neuron 218...
# Prompting neuron 172...
# Prompting neuron 41...
# Prompting neuron 116...
# Prompting neuron 194...
# Prompting neuron 155...
# Prompting neuron 38...
# Prompting neuron 207...
# Prompting neuron 63...
# Prompting neuron 242...
# Prompting neuron 109...
# Prompting neuron 46...
# Prompting neuron 225...
# Prompting neuron 22...
# Prompting neuron 99...
# Prompting neuron 97...
# Prompting neuron 235...
# Prompting neuron 170...
# Prompting neuron 119...
# Prompting neuron 125...
# Prompting neuron 192...
# Prompting neuron 202...
# Prompting neuron 51...
# Prompting neuron 111...
# Prompting neuron 186...
# Prompting neuron 152...
# Prompting neuron 240...
# Prompting neuron 87...
# Prompting neuron 47...
# Prompting neuron 128...
# Prompting neuron 223...
# Prompting neuron 77...
# Prompting neuron 2...
# Prompting neuron 215...
# Prompting neuron 250...
# Prompting neuron 120...
# Prompting neuron 103...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_3_15.csv
# Prompting neuron 91...
# Prompting neuron 256...
# Prompting neuron 216...
# Prompting neuron 203...
# Prompting neuron 78...
# Prompting neuron 16...
# Prompting neuron 110...
# Prompting neuron 12...
# Prompting neuron 160...
# Prompting neuron 154...
# Prompting neuron 243...
# Prompting neuron 252...
# Prompting neuron 253...
# Prompting neuron 218...
# Prompting neuron 172...
# Prompting neuron 41...
# Prompting neuron 116...
# Prompting neuron 194...
# Prompting neuron 155...
# Prompting neuron 38...
# Prompting neuron 207...
# Prompting neuron 63...
# Prompting neuron 242...
# Prompting neuron 109...
# Prompting neuron 46...
# Prompting neuron 225...
# Prompting neuron 22...
# Prompting neuron 99...
# Prompting neuron 97...
# Prompting neuron 235...
# Prompting neuron 170...
# Prompting neuron 119...
# Prompting neuron 125...
# Prompting neuron 192...
# Prompting neuron 202...
# Prompting neuron 51...
# Prompting neuron 111...
# Prompting neuron 186...
# Prompting neuron 152...
# Prompting neuron 240...
# Prompting neuron 87...
# Prompting neuron 47...
# Prompting neuron 128...
# Prompting neuron 223...
# Prompting neuron 77...
# Prompting neuron 2...
# Prompting neuron 215...
# Prompting neuron 250...
# Prompting neuron 120...
# Prompting neuron 103...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_3_20.csv
# Loading activations from: /Users/sinievanderben/Documents/ETH/tech/cosy/LLM_activations/activations/val_resnet18-layer4.pt
# Activation shape: torch.Size([50000, 512])
# Top-X indices shape: torch.Size([512, 20])
# Random sample shape: torch.Size([512, 20])
# Prompting neuron 232...
# Prompting neuron 324...
# Prompting neuron 28...
# Prompting neuron 471...
# Prompting neuron 45...
# Prompting neuron 321...
# Prompting neuron 436...
# Prompting neuron 388...
# Prompting neuron 393...
# Prompting neuron 501...
# Prompting neuron 381...
# Prompting neuron 460...
# Prompting neuron 296...
# Prompting neuron 267...
# Prompting neuron 446...
# Prompting neuron 15...
# Prompting neuron 58...
# Prompting neuron 138...
# Prompting neuron 318...
# Prompting neuron 295...
# Prompting neuron 104...
# Prompting neuron 315...
# Prompting neuron 46...
# Prompting neuron 190...
# Prompting neuron 32...
# Prompting neuron 308...
# Prompting neuron 364...
# Prompting neuron 263...
# Prompting neuron 26...
# Prompting neuron 135...
# Prompting neuron 435...
# Prompting neuron 257...
# Prompting neuron 112...
# Prompting neuron 270...
# Prompting neuron 231...
# Prompting neuron 78...
# Prompting neuron 56...
# Prompting neuron 353...
# Prompting neuron 365...
# Prompting neuron 320...
# Prompting neuron 300...
# Prompting neuron 370...
# Prompting neuron 406...
# Prompting neuron 109...
# Prompting neuron 260...
# Prompting neuron 107...
# Prompting neuron 367...
# Prompting neuron 205...
# Prompting neuron 248...
# Prompting neuron 325...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_4_1.csv
# Prompting neuron 232...
# Prompting neuron 324...
# Prompting neuron 28...
# Prompting neuron 471...
# Prompting neuron 45...
# Prompting neuron 321...
# Prompting neuron 436...
# Prompting neuron 388...
# Prompting neuron 393...
# Prompting neuron 501...
# Prompting neuron 381...
# Prompting neuron 460...
# Prompting neuron 296...
# Prompting neuron 267...
# Prompting neuron 446...
# Prompting neuron 15...
# Prompting neuron 58...
# Prompting neuron 138...
# Prompting neuron 318...
# Prompting neuron 295...
# Prompting neuron 104...
# Prompting neuron 315...
# Prompting neuron 46...
# Prompting neuron 190...
# Prompting neuron 32...
# Prompting neuron 308...
# Prompting neuron 364...
# Prompting neuron 263...
# Prompting neuron 26...
# Prompting neuron 135...
# Prompting neuron 435...
# Prompting neuron 257...
# Prompting neuron 112...
# Prompting neuron 270...
# Prompting neuron 231...
# Prompting neuron 78...
# Prompting neuron 56...
# Prompting neuron 353...
# Prompting neuron 365...
# Prompting neuron 320...
# Prompting neuron 300...
# Prompting neuron 370...
# Prompting neuron 406...
# Prompting neuron 109...
# Prompting neuron 260...
# Prompting neuron 107...
# Prompting neuron 367...
# Prompting neuron 205...
# Prompting neuron 248...
# Prompting neuron 325...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_4_5.csv
# Prompting neuron 232...
# Prompting neuron 324...
# Prompting neuron 28...
# Prompting neuron 471...
# Prompting neuron 45...
# Prompting neuron 321...
# Prompting neuron 436...
# Prompting neuron 388...
# Prompting neuron 393...
# Prompting neuron 501...
# Prompting neuron 381...
# Prompting neuron 460...
# Prompting neuron 296...
# Prompting neuron 267...
# Prompting neuron 446...
# Prompting neuron 15...
# Prompting neuron 58...
# Prompting neuron 138...
# Prompting neuron 318...
# Prompting neuron 295...
# Prompting neuron 104...
# Prompting neuron 315...
# Prompting neuron 46...
# Prompting neuron 190...
# Prompting neuron 32...
# Prompting neuron 308...
# Prompting neuron 364...
# Prompting neuron 263...
# Prompting neuron 26...
# Prompting neuron 135...
# Prompting neuron 435...
# Prompting neuron 257...
# Prompting neuron 112...
# Prompting neuron 270...
# Prompting neuron 231...
# Prompting neuron 78...
# Prompting neuron 56...
# Prompting neuron 353...
# Prompting neuron 365...
# Prompting neuron 320...
# Prompting neuron 300...
# Prompting neuron 370...
# Prompting neuron 406...
# Prompting neuron 109...
# Prompting neuron 260...
# Prompting neuron 107...
# Prompting neuron 367...
# Prompting neuron 205...
# Prompting neuron 248...
# Prompting neuron 325...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_4_10.csv
# Prompting neuron 232...
# Prompting neuron 324...
# Prompting neuron 28...
# Prompting neuron 471...
# Prompting neuron 45...
# Prompting neuron 321...
# Prompting neuron 436...
# Prompting neuron 388...
# Prompting neuron 393...
# Prompting neuron 501...
# Prompting neuron 381...
# Prompting neuron 460...
# Prompting neuron 296...
# Prompting neuron 267...
# Prompting neuron 446...
# Prompting neuron 15...
# Prompting neuron 58...
# Prompting neuron 138...
# Prompting neuron 318...
# Prompting neuron 295...
# Prompting neuron 104...
# Prompting neuron 315...
# Prompting neuron 46...
# Prompting neuron 190...
# Prompting neuron 32...
# Prompting neuron 308...
# Prompting neuron 364...
# Prompting neuron 263...
# Prompting neuron 26...
# Prompting neuron 135...
# Prompting neuron 435...
# Prompting neuron 257...
# Prompting neuron 112...
# Prompting neuron 270...
# Prompting neuron 231...
# Prompting neuron 78...
# Prompting neuron 56...
# Prompting neuron 353...
# Prompting neuron 365...
# Prompting neuron 320...
# Prompting neuron 300...
# Prompting neuron 370...
# Prompting neuron 406...
# Prompting neuron 109...
# Prompting neuron 260...
# Prompting neuron 107...
# Prompting neuron 367...
# Prompting neuron 205...
# Prompting neuron 248...
# Prompting neuron 325...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_4_15.csv
# Prompting neuron 232...
# Prompting neuron 324...
# Prompting neuron 28...
# Prompting neuron 471...
# Prompting neuron 45...
# Prompting neuron 321...
# Prompting neuron 436...
# Prompting neuron 388...
# Prompting neuron 393...
# Prompting neuron 501...
# Prompting neuron 381...
# Prompting neuron 460...
# Prompting neuron 296...
# Prompting neuron 267...
# Prompting neuron 446...
# Prompting neuron 15...
# Prompting neuron 58...
# Prompting neuron 138...
# Prompting neuron 318...
# Prompting neuron 295...
# Prompting neuron 104...
# Prompting neuron 315...
# Prompting neuron 46...
# Prompting neuron 190...
# Prompting neuron 32...
# Prompting neuron 308...
# Prompting neuron 364...
# Prompting neuron 263...
# Prompting neuron 26...
# Prompting neuron 135...
# Prompting neuron 435...
# Prompting neuron 257...
# Prompting neuron 112...
# Prompting neuron 270...
# Prompting neuron 231...
# Prompting neuron 78...
# Prompting neuron 56...
# Prompting neuron 353...
# Prompting neuron 365...
# Prompting neuron 320...
# Prompting neuron 300...
# Prompting neuron 370...
# Prompting neuron 406...
# Prompting neuron 109...
# Prompting neuron 260...
# Prompting neuron 107...
# Prompting neuron 367...
# Prompting neuron 205...
# Prompting neuron 248...
# Prompting neuron 325...
# Number of responses: 50
# Data successfully written to experiments/prompts_6/layer_4_20.csv
# Prompt successfully written to experiments/prompts_6/prompt.txt
